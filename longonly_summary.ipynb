# %% [markdown]
# # longonly_summary
#
# This notebook summarises major performance statistics for long-only futures contracts provided by Quandl.

# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt

from adagio.stats.performance import Performance, PerfStats
from adagio.utils import keys
from adagio.utils.const import FuturesInfo
from adagio.utils.mongo import get_library

# %% [markdown]
# First, connect to the arctic library named "longonly" to retrieve long-only data.

# %%
library = get_library(keys.backtest)

# %% [markdown]
# Let's see major statistics for each contract. This is done by looping over all futures contracts saved in the db.

# %%
results = []
for fut in FuturesInfo:
    key, futures_info = fut.name, fut.value
    
    symbol = library.list_symbols(lo_ticker=key)[0]
    item = library.read(symbol)
    data = item.data
    
    longonly_returns = data.final_net_returns
    stats = longonly_returns.add(1).cumprod().pipe(Performance).summary()
    
    results.append([
            futures_info.full_name,
            futures_info.asset_class,
            longonly_returns.index[0].strftime("%Y%m%d"),
            stats.loc[PerfStats.ANN_RETURN.value, longonly_returns.name],
            stats.loc[PerfStats.ANN_VOL.value, longonly_returns.name],
            stats.loc[PerfStats.SHARPE.value, longonly_returns.name],
            stats.loc[PerfStats.SKEWNESS.value, longonly_returns.name]
        ])
    
result = pd.DataFrame(results, columns=[
        "contract", "asset class", "start date",
        PerfStats.ANN_RETURN.value, 
        PerfStats.ANN_VOL.value,
        PerfStats.SHARPE.value,
        PerfStats.SKEWNESS.value,
]).set_index("contract")

# %% [markdown]
# # Long-only summary
#
# This table displays contract information such as the contract name as well as statistics. Stats are for 1st contracts rolled a few days before its delivery. Bar charts are superimposed for annualised returns and Sharpe ratios based on its value.   Statistics are based on its local currencies.
# Note that some start dates do not match the exact inception of the futures contract. Those may be truncated due to the data limitation of Quandl.

# %%
(result.style.format({
        PerfStats.ANN_RETURN.value: "{:.2%}",
        PerfStats.ANN_VOL.value: "{:.2%}",
        PerfStats.SHARPE.value: "{:.2f}",
        PerfStats.SKEWNESS.value: "{:.2f}",
    })
 .bar(subset=PerfStats.ANN_RETURN.value)
 .bar(subset=PerfStats.SHARPE.value))
# Out:
#         <style  type="text/css" >
#
#
#             #T_df5a7c38_607c_11e7_a5fa_00acaa96c656row0_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 81.55143767062326%, transparent 0%);
#
#             }
#
#             #T_df5a7c38_607c_11e7_a5fa_00acaa96c656row0_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 38.87823260002616%, transparent 0%);
#
#             }
#
#             #T_df5a7c38_607c_11e7_a5fa_00acaa96c656row1_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 84.77489130736005%, transparent 0%);
#
#             }
#
#             #T_df5a7c38_607c_11e7_a5fa_00acaa96c656row1_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 43.99094961775868%, transparent 0%);
#
#             }
#
#             #T_df5a7c38_607c_11e7_a5fa_00acaa96c656row2_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 83.4655333608645%, transparent 0%);
#
#             }
#
#             #T_df5a7c38_607c_11e7_a5fa_00acaa96c656row2_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 37.640211414408824%, transparent 0%);
#
#             }
#
#             #T_df5a7c38_607c_11e7_a5fa_00acaa96c656row3_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 87.75361227876452%, transparent 0%);
#
#             }
#
#             #T_df5a7c38_607c_11e7_a5fa_00acaa96c656row3_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 41.14690019937474%, transparent 0%);
#
#             }
#
#             #T_df5a7c38_607c_11e7_a5fa_00acaa96c656row4_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 81.50148316910648%, transparent 0%);
#
#             }
#
#             #T_df5a7c38_607c_11e7_a5fa_00acaa96c656row4_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 38.99619349322235%, transparent 0%);
#
#             }
#
#             #T_df5a7c38_607c_11e7_a5fa_00acaa96c656row5_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 86.52572595398688%, transparent 0%);
#
#             }
#
#             #T_df5a7c38_607c_11e7_a5fa_00acaa96c656row5_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 45.6590631398763%, transparent 0%);
#
#             }
#
#             #T_df5a7c38_607c_11e7_a5fa_00acaa96c656row6_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 83.98503282977553%, transparent 0%);
#
#             }
#
#             #T_df5a7c38_607c_11e7_a5fa_00acaa96c656row6_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 41.538977445884285%, transparent 0%);
#
#             }
#
#             #T_df5a7c38_607c_11e7_a5fa_00acaa96c656row7_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 86.7831341117283%, transparent 0%);
#
#             }
#
#             #T_df5a7c38_607c_11e7_a5fa_00acaa96c656row7_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 42.23931969708504%, transparent 0%);
#
#             }
#
#             #T_df5a7c38_607c_11e7_a5fa_00acaa96c656row8_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 88.21804356963055%, transparent 0%);
#
#             }
#
#             #T_df5a7c38_607c_11e7_a5fa_00acaa96c656row8_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 53.49023577934156%, transparent 0%);
#
#             }
#
#             #T_df5a7c38_607c_11e7_a5fa_00acaa96c656row9_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 90.52062864447798%, transparent 0%);
#
#             }
#
#             #T_df5a7c38_607c_11e7_a5fa_00acaa96c656row9_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 58.04563778826807%, transparent 0%);
#
#             }
#
#             #T_df5a7c38_607c_11e7_a5fa_00acaa96c656row10_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 88.22601668665621%, transparent 0%);
#
#             }
#
#             #T_df5a7c38_607c_11e7_a5fa_00acaa96c656row10_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 46.728542750210664%, transparent 0%);
#
#             }
#
#             #T_df5a7c38_607c_11e7_a5fa_00acaa96c656row11_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 75.99740718215602%, transparent 0%);
#
#             }
#
#             #T_df5a7c38_607c_11e7_a5fa_00acaa96c656row11_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 30.290345023180667%, transparent 0%);
#
#             }
#
#             #T_df5a7c38_607c_11e7_a5fa_00acaa96c656row12_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 80.0325641419353%, transparent 0%);
#
#             }
#
#             #T_df5a7c38_607c_11e7_a5fa_00acaa96c656row12_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 34.95202098479623%, transparent 0%);
#
#             }
#
#             #T_df5a7c38_607c_11e7_a5fa_00acaa96c656row13_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 84.29385070933047%, transparent 0%);

# %%
fig, ax = plt.subplots(figsize=(16, 4))
ax.set_title("Long-only Sharpe ratio")
ax.set_ylabel("Sharpe ratio")
result[PerfStats.SHARPE.value].plot(kind="bar", ax=ax, grid=True);

# %% [markdown]
# # Plot cumulative return series
#
# Here only E-mini futures is shown.

# %%
for fut in FuturesInfo:
    symbol = library.list_symbols(lo_ticker=fut.name)[0]
    item = library.read(symbol)
    data = item.data
    
    fig, ax = plt.subplots()
    data.final_net_returns.cumsum().plot(grid=True, ax=ax);
    ax.set_title('Cumulative returns: {}'.format(fut.value.full_name))
    
    break
